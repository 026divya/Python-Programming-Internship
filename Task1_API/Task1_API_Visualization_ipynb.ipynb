# %%
# !pip install requests matplotlib
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import requests

API_KEY = "6a7f2e999bac54152100eb4224722df6"

city = "Bangalore"

url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)

data = response.json()

print(data)
# Out:
# {'coord': {'lon': 77.6033, 'lat': 12.9762}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 33.72, 'feels_like': 31.3, 'temp_min': 33.72, 'temp_max': 33.72, 'pressure': 1010, 'humidity': 14, 'sea_level': 1010, 'grnd_level': 914}, 'visibility': 10000, 'wind': {'speed': 4.5, 'deg': 101, 'gust': 5.6}, 'clouds': {'all': 5}, 'dt': 1774595369, 'sys': {'country': 'IN', 'sunrise': 1774572556, 'sunset': 1774616440}, 'timezone': 19800, 'id': 1277333, 'name': 'Bengaluru', 'cod': 200}

# %%
import requests

API_KEY = "6a7f2e999bac54152100eb4224722df6"

city = "Bangalore"

url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={API_KEY}&units=metric"

response = requests.get(url)

data = response.json()

temperatures = []
dates = []

# Check API response
if "list" not in data:
    print("API Error:")
    print(data)

else:
    for item in data["list"][:8]:
        temperatures.append(item["main"]["temp"])
        dates.append(item["dt_txt"])

    print("Weather data fetched successfully!")
# Out:
# Weather data fetched successfully!

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.plot(dates, temperatures)

plt.xticks(rotation=90)

plt.title("Temperature Forecast for Bangalore")

plt.xlabel("Date")

plt.ylabel("Temperature (°C)")

plt.tight_layout()

plt.show()
